# %%
# !pip install datasets
# !pip install sklearn
# !pip install pandas
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...

# %%
import pandas as pd
from datasets import Dataset
from sklearn.model_selection import train_test_split

# %%
data = [
    {"input": "question: What is DRDO, and what are its primary objectives?", "output": "DRDO (Defence Research and Development Organisation) is an Indian government agency responsible for developing defense technologies and systems, including weapons, equipment, and military technology to enhance national security."},
    {"input": "question: Explain the concept of missile guidance systems.", "output": "Missile guidance systems direct a missile to its target using methods such as inertial guidance, GPS, radar, or optical guidance to ensure accurate delivery to the intended location."},
    {"input": "question: What is the difference between a radar and a sonar system?", "output": "Radar uses radio waves to detect and locate objects in the air or on the ground, while sonar uses sound waves to detect and locate objects underwater."},
    {"input": "question: How does an active radar system work?", "output": "An active radar system transmits its own signal and detects the reflected signals from targets, measuring the time delay and intensity to determine the target's distance, speed, and direction."},
    {"input": "question: What are the key components of a communication satellite system?", "output": "Key components include satellites (with transponders and antennas), ground stations (for signal transmission and reception), and communication links (for relaying data)."},
    {"input": "question: Explain the principle of stealth technology.", "output": "Stealth technology minimizes an object's visibility to radar, infrared, and other detection methods by using materials and design techniques to reduce its radar cross-section and thermal signature."},
    {"input": "question: What is the significance of cryptography in defense systems?", "output": "Cryptography ensures secure communication by encrypting data, preventing unauthorized access, and protecting sensitive information from interception and decryption."},
    {"input": "question: How does a surface-to-air missile (SAM) system work?", "output": "A SAM system detects, tracks, and intercepts incoming airborne threats using radar and missile guidance systems, launching missiles to destroy or neutralize the target."},
    {"input": "question: What is the role of electronic warfare (EW) in modern defense systems?", "output": "Electronic warfare involves using electromagnetic energy to disrupt or deceive enemy electronic systems, including radar, communications, and navigation, to gain a tactical advantage."},
    {"input": "question: Describe the concept of an autonomous vehicle in defense applications.", "output": "Autonomous vehicles use sensors, artificial intelligence, and navigation systems to operate without human intervention, performing tasks like reconnaissance, logistics, and combat support."},
    {"input": "question: What is the difference between a passive and an active sonar system?", "output": "Passive sonar systems listen for sounds emitted by underwater objects, while active sonar systems send out sound waves and measure their reflections to detect and locate objects."},
    {"input": "question: How do you ensure the reliability and safety of defense systems?", "output": "Reliability and safety are ensured through rigorous testing, quality assurance processes, adherence to standards, and failure analysis to identify and mitigate potential issues."},
    {"input": "question: What is a phased array radar, and how does it differ from a traditional radar?", "output": "A phased array radar uses electronically controlled antennas to steer and focus the radar beam without physically moving the antenna, offering faster scanning and tracking compared to traditional radar systems."},
    {"input": "question: Explain the concept of anti-ballistic missile (ABM) systems.", "output": "ABM systems are designed to intercept and destroy ballistic missiles before they reach their targets using methods such as kinetic kill vehicles, interceptors, and radar tracking."},
    {"input": "question: What are the key principles of propulsion systems used in missiles?", "output": "Key principles include thrust generation through combustion or other means, guidance and control for trajectory adjustment, and propulsion efficiency to achieve desired speed and range."},
    {"input": "question: How does a thermal imaging system work?", "output": "A thermal imaging system detects infrared radiation emitted by objects and converts it into an image, allowing visualization of heat patterns and detecting objects in low-light or obscured conditions."},
    {"input": "question: What is the role of simulation and modeling in defense research?", "output": "Simulation and modeling are used to test and evaluate defense systems in virtual environments, analyze performance, predict outcomes, and improve designs without physical prototypes."},
    {"input": "question: What are the key challenges in developing advanced radar systems?", "output": "Challenges include minimizing interference, improving resolution and detection range, managing signal processing, and enhancing target tracking capabilities in complex environments."},
    {"input": "question: How does a ground-based radar system differ from an airborne radar system?", "output": "Ground-based radar systems are stationary and monitor airspace or ground targets from a fixed location, while airborne radar systems are mounted on aircraft and provide coverage from various altitudes and angles."},
    {"input": "question: What is the importance of signal processing in defense technology?", "output": "Signal processing enhances the quality and accuracy of data obtained from sensors and communication systems, enabling effective detection, classification, and response to various threats."},
    {"input": "question: What is the purpose of a countermeasure system in defense applications?", "output": "Countermeasure systems are designed to protect against and neutralize enemy threats, such as jamming, spoofing, or intercepting incoming attacks using defensive technologies."},
    {"input": "question: How does a GPS system contribute to navigation and targeting?", "output": "A GPS system provides precise location and timing information using satellite signals, aiding in accurate navigation, targeting, and coordination for military and defense operations."},
    {"input": "question: What are the key considerations in designing military-grade communication systems?", "output": "Key considerations include security (encryption), reliability, robustness in harsh environments, interoperability, and resilience to electronic warfare and interference."},
    {"input": "question: Explain the concept of a command and control (C2) system.", "output": "A C2 system integrates data and communications to facilitate decision-making, coordination, and control of military operations, ensuring effective management of resources and personnel."},
    {"input": "question: What is a smart weapon, and how does it differ from traditional weapons?", "output": "Smart weapons use advanced guidance systems, sensors, and targeting technology to improve accuracy and effectiveness, unlike traditional weapons which rely on less precise targeting methods."},
    {"input": "question: How do you evaluate the performance of a defense system under realistic conditions?", "output": "Performance is evaluated through field tests, simulations, and exercises that replicate real-world scenarios, assessing the system's effectiveness, reliability, and operational capabilities."},
    {"input": "question: What are the advantages of using unmanned aerial vehicles (UAVs) in defense operations?", "output": "UAVs provide real-time surveillance, reconnaissance, and strike capabilities without risking human lives, offering flexibility, precision, and extended operational reach."},
    {"input": "question: How does a guidance system ensure the accuracy of a missile?", "output": "A guidance system uses sensors, algorithms, and feedback mechanisms to track and adjust the missile's trajectory, ensuring it remains on course to accurately reach its target."},
    {"input": "question: What is the role of a defense research lab in the development of military technology?", "output": "Defense research labs conduct research, develop prototypes, and test advanced technologies to enhance military capabilities, address specific defense needs, and drive innovation."},
    {"input": "question: How do you address cybersecurity concerns in defense systems?", "output": "Address cybersecurity concerns through robust encryption, secure protocols, regular security audits, and threat detection systems to protect against unauthorized access and cyber attacks."},
    {"input": "question: What are the main types of defense sensors used in surveillance?", "output": "Main types include radar sensors, infrared sensors, optical sensors, and acoustic sensors, each providing different types of information and capabilities for detecting and tracking threats."},
    {"input": "question: Explain the concept of a defense network architecture.", "output": "A defense network architecture involves the design and integration of various communication and information systems to ensure secure, efficient, and reliable operation for military and defense purposes."},
    {"input": "question: What is a naval combat system, and what are its components?", "output": "A naval combat system integrates sensors, weapons, and command systems on a naval vessel, including radar, sonar, fire control systems, and communication equipment, to manage and execute combat operations."},
    {"input": "question: How does a fiber-optic communication system work?", "output": "A fiber-optic communication system transmits data as light pulses through optical fibers, providing high-speed, high-capacity, and low-loss communication over long distances."},
    {"input": "question: What are the key factors in designing an effective missile defense system?", "output": "Key factors include detection and tracking accuracy, interceptor capabilities, response time, and integration with command and control systems for effective threat neutralization."},
    {"input": "question: What is a defense technology demonstration, and why is it important?", "output": "A defense technology demonstration showcases the capabilities and performance of new technologies or systems in a controlled environment, validating their effectiveness and feasibility before deployment."},
    {"input": "question: How does a radar cross-section (RCS) impact the detectability of an object?", "output": "A larger RCS increases an object's visibility to radar, making it easier to detect. Reducing RCS through stealth technology decreases detectability and enhances survivability."},
    {"input": "question: What are the challenges in developing advanced navigation systems for defense applications?", "output": "Challenges include ensuring accuracy in various environments, integrating multiple sensor inputs, maintaining robustness against jamming and spoofing, and adapting to dynamic conditions."},
    {"input": "question: Explain the concept of a tactical data link in military communications.", "output": "A tactical data link facilitates real-time exchange of information between military platforms, such as aircraft, ships, and ground forces, improving situational awareness and coordination."},
    {"input": "question: What is the role of electronic counter-countermeasures (ECCM) in defense systems?", "output": "ECCM techniques protect electronic systems from enemy countermeasures, such as jamming or spoofing, ensuring reliable performance and maintaining communication and radar effectiveness."},
    {"input": "question: How do you integrate new technologies into existing defense systems?", "output": "Integration involves assessing compatibility, modifying interfaces, conducting testing and validation, and ensuring that new technologies enhance system capabilities without compromising performance."},
    {"input": "question: What is a defense simulation and training system, and what are its benefits?", "output": "A defense simulation and training system replicates real-world scenarios for training personnel, allowing them to practice and develop skills in a controlled environment, enhancing readiness and effectiveness."},
    {"input": "question: How does a high-energy laser weapon system work?", "output": "A high-energy laser weapon system uses focused laser beams to damage or destroy targets by delivering concentrated energy, capable of engaging threats at high speed and precision."},
    {"input": "question: What are the key considerations for designing a military-grade electronic device?", "output": "Key considerations include durability, reliability, resistance to environmental factors, secure communication, and compliance with defense standards and specifications."},
    {"input": "question: How do you test and validate a new defense system?", "output": "Testing and validation involve conducting laboratory experiments, field trials, and operational assessments to evaluate performance, reliability, and effectiveness against specified criteria."},
    {"input": "question: What is the importance of interoperability in defense systems?", "output": "Interoperability ensures that different defense systems and platforms can work together seamlessly, exchanging information and coordinating actions to achieve unified operational objectives."},
    {"input": "question: How does a defense research project transition from development to production?", "output": "The transition involves finalizing designs, scaling up production processes, conducting production testing, ensuring quality control, and coordinating with manufacturing and supply chain partners."},
    {"input": "question: What are the key factors in designing a combat vehicle?", "output": "Key factors include armor protection, mobility, weapon systems, communication and control systems, and integration with support and maintenance infrastructure."},
    {"input": "question: Explain the concept of an unmanned ground vehicle (UGV) and its applications.", "output": "An unmanned ground vehicle (UGV) operates without human operators on board, used for tasks such as reconnaissance, bomb disposal, and logistics support, providing safety and efficiency in dangerous environments."},
    {"input": "question: What is the role of research and development in advancing defense technology?", "output": "Research and development drive innovation in defense technology, enabling the creation of new systems, improving existing capabilities, and addressing emerging threats to maintain strategic advantage and security."},
    {
        "input": "What is the function of a phase-locked loop (PLL) in communication systems?",
        "output": "A phase-locked loop (PLL) is used to synchronize an oscillator's phase and frequency with that of an input signal. It's commonly used for frequency synthesis, demodulation, and clock generation in communication systems."
    },
    {
        "input": "Explain the difference between TDMA and FDMA.",
        "output": "TDMA (Time Division Multiple Access) divides the frequency band into time slots, allowing multiple users to share the same frequency band by transmitting in different time slots. FDMA (Frequency Division Multiple Access) assigns separate frequency bands to each user, allowing simultaneous transmission on different frequencies."
    },
    {
        "input": "What is a modulation index in amplitude modulation?",
        "output": "The modulation index in amplitude modulation is the ratio of the amplitude of the modulating signal to the amplitude of the carrier signal. It determines the extent of modulation applied to the carrier."
    },
    {
        "input": "Describe the working of a superheterodyne receiver.",
        "output": "A superheterodyne receiver converts a received signal to a lower intermediate frequency (IF) for easier processing. It uses a mixer to combine the incoming signal with a locally generated signal, producing an IF that is then filtered and amplified."
    },
    {
        "input": "What is the purpose of a band-pass filter in communication systems?",
        "output": "A band-pass filter allows frequencies within a specific range to pass through while attenuating frequencies outside that range. It is used in communication systems to select the desired signal frequency and reject unwanted signals."
    },
    {
        "input": "Explain the concept of VSWR and its importance.",
        "output": "VSWR (Voltage Standing Wave Ratio) is a measure of impedance matching in transmission lines. A lower VSWR indicates better matching, resulting in less signal reflection and higher efficiency in the transmission system."
    },
{         "input": "What is the Nyquist theorem, and why is it important?",         "output": "The Nyquist theorem states that a signal must be sampled at least twice its highest frequency component to be accurately reconstructed. It's crucial in digital signal processing to avoid aliasing and loss of information."     },     {         "input": "Describe the working principle of a radar system.",         "output": "A radar system works by transmitting radio waves and detecting the reflected signals from objects. The time delay between transmission and reception is used to calculate the distance, while the Doppler shift in frequency helps determine the speed of the object."     },     {         "input": "What is the difference between analog and digital signals?",         "output": "Analog signals are continuous and can take any value within a range, while digital signals are discrete and represent information using binary values (0s and 1s). Digital signals are less susceptible to noise and can be easily processed by digital circuits."     },     {         "input": "Explain the concept of frequency reuse in cellular communication.",         "output": "Frequency reuse is a technique used in cellular communication to improve spectrum efficiency by using the same frequency channels in different cells separated by a sufficient distance to avoid interference. This allows more users to share the limited frequency spectrum."     },     {         "input": "What is an antenna gain, and how is it measured?",         "output": "Antenna gain is a measure of how effectively an antenna directs or concentrates radio waves in a particular direction. It is usually measured in dBi (decibels relative to an isotropic radiator) or dBd (decibels relative to a dipole antenna)."     },     {         "input": "Describe the working principle of an operational amplifier (op-amp).",         "output": "An operational amplifier (op-amp) is a high-gain voltage amplifier with differential inputs and a single output. It amplifies the difference between the input voltages and is widely used in signal processing, filtering, and other analog applications."     },
{         "input": "What is a Smith chart, and how is it used?",         "output": "A Smith chart is a graphical tool used to represent complex impedance and reflection coefficients in transmission lines. It is commonly used in RF engineering to solve problems related to matching, impedance, and reflection in transmission systems."     },     {         "input": "Explain the concept of orthogonal frequency-division multiplexing (OFDM).",         "output": "OFDM is a digital modulation technique that divides a high-data-rate signal into multiple lower-rate subcarriers, each modulated with a different frequency. These subcarriers are orthogonal to each other, allowing for efficient use of the spectrum and resistance to interference."     },     {         "input": "What is the purpose of an equalizer in communication systems?",         "output": "An equalizer compensates for signal distortion and inter-symbol interference caused by transmission through a channel. It adjusts the amplitude and phase of received signals to match the original transmitted signal, improving the quality of data transmission."     },     {         "input": "Describe the working principle of a microwave oven.",         "output": "A microwave oven uses microwaves to heat food by causing water molecules in the food to vibrate and generate heat. The microwaves are produced by a magnetron, and the oven cavity is designed to reflect the microwaves, ensuring even heating."     },     {         "input": "What is the significance of the S-parameters in network analysis?",         "output": "S-parameters (scattering parameters) describe the behavior of RF networks in terms of reflection and transmission coefficients. They are used to characterize the performance of components like amplifiers, filters, and antennas in high-frequency circuits."     },     {         "input": "Explain the difference between AM and FM modulation.",         "output": "In amplitude modulation (AM), the amplitude of the carrier signal is varied in proportion to the message signal. In frequency modulation (FM), the frequency of the carrier signal is varied according to the message signal, providing better noise immunity than AM."     },
  {         "input": "What is a standing wave ratio (SWR), and why is it important?",         "output": "SWR (Standing Wave Ratio) measures the efficiency of power transmission in a transmission line. A lower SWR indicates better impedance matching and less signal reflection, which is important for maximizing power transfer and minimizing losses."     },     {         "input": "Describe the concept of impedance matching in transmission lines.",         "output": "Impedance matching ensures that the impedance of the source, transmission line, and load are equal, minimizing signal reflection and maximizing power transfer. It is crucial in RF circuits to achieve efficient signal transmission."     },     {         "input": "What is the role of a balun in RF systems?",         "output": "A balun (balanced-unbalanced transformer) converts a balanced signal (equal and opposite currents) to an unbalanced signal (single-ended) or vice versa. It is used in RF systems to connect balanced antennas to unbalanced transmission lines, minimizing signal loss and interference."     },     {         "input": "Explain the working of a phase shifter in phased array antennas.",         "output": "A phase shifter controls the phase of the signal feeding each element in a phased array antenna, allowing the direction of the beam to be electronically steered without physically moving the antenna. It enables rapid scanning and targeting in radar and communication systems."     },     {         "input": "What is the importance of the Friis transmission equation in wireless communication?",         "output": "The Friis transmission equation calculates the power received by an antenna from a transmitter, considering the distance between them, the frequency of the signal, and the gains of the antennas. It is important for designing and analyzing wireless communication links."     },
  {         "input": "Describe the concept of frequency hopping in spread spectrum communication.",         "output": "Frequency hopping is a spread spectrum technique where the carrier frequency rapidly changes according to a predefined pattern, reducing the likelihood of interference and interception. It is used in military and secure communication systems for enhanced security and robustness."     },     {         "input": "What is the purpose of a circulator in microwave circuits?",         "output": "A circulator is a passive microwave device that routes signals from one port to the next in a specific direction. It is commonly used to isolate different parts of a circuit, allowing signals to flow in one direction while preventing reflections."     },     {         "input": "Explain the concept of diversity reception in wireless communication.",         "output": "Diversity reception involves using multiple antennas or receivers to capture different versions of the same signal. By combining these signals, the effects of fading and interference can be minimized, improving the reliability and quality of the received signal."     },     {         "input": "What is the purpose of a low-noise amplifier (LNA) in RF systems?",         "output": "A low-noise amplifier (LNA) amplifies weak signals received by an antenna while adding minimal noise. It is placed at the front end of an RF system to improve the signal-to-noise ratio and enhance the overall performance of the communication system."     },     {         "input": "Describe the concept of impedance matching using a quarter-wave transformer.",         "output": "A quarter-wave transformer is a transmission line segment with a length of one-quarter of the wavelength at the operating frequency. It is used to match the impedance between a load and a transmission line, minimizing reflections and maximizing power transfer."     },     {         "input": "What is the role of a duplexer in a communication system?",         "output": "A duplexer allows simultaneous transmission and reception of signals using the same antenna by separating the transmit and receive paths. It prevents the transmitted signal from interfering with the received signal, enabling full-duplex communication."     },     {         "input": "Explain the working principle of a radar system.",         "output": "A radar system works by transmitting radio waves and detecting the reflected signals from objects. The time delay between transmission and reception is used to calculate the distance, while the Doppler shift in frequency helps determine the speed of the object."     },     {         "input": "How do you ensure the reliability of a missile guidance system?",         "output": "Reliability in a missile guidance system is ensured through rigorous testing, redundancy in critical components, robust algorithms, and fault-tolerant design. Regular maintenance and software updates also play a key role."     },     {         "input": "Discuss the design considerations for an unmanned aerial vehicle (UAV).",         "output": "Design considerations for UAVs include aerodynamic efficiency, lightweight materials, power management, control systems, payload capacity, communication systems, and safety features such as fail-safe mechanisms."     },     {         "input": "What is the difference between a microprocessor and a microcontroller?",         "output": "A microprocessor is the central unit of a computer system, primarily focused on processing tasks. A microcontroller, on the other hand, integrates a processor with memory and input/output peripherals on a single chip, designed for controlling embedded systems."     },     {         "input": "Explain the working principle of a jet engine.",         "output": "A jet engine works on the principle of Newton's Third Law. It sucks in air, compresses it, mixes it with fuel, and ignites the mixture. The resulting high-speed exhaust gases produce thrust, propelling the aircraft forward."     },
{         "input": "How do you design a robust control system for an autonomous vehicle?",         "output": "Designing a robust control system for an autonomous vehicle involves sensor fusion, reliable algorithms for path planning and obstacle avoidance, redundancy in critical systems, and real-time processing capabilities to ensure safe and efficient operation."     },     {         "input": "What are the key components of a satellite communication system?",         "output": "Key components of a satellite communication system include the satellite transponder, ground station antennas, uplink and downlink frequency channels, modems, and amplifiers. These components work together to transmit and receive signals over long distances."     },     {         "input": "Describe the working of a GPS system.",         "output": "A GPS system works by using a network of satellites that transmit signals to receivers on Earth. The receiver calculates its position by measuring the time it takes for the signals from multiple satellites to reach it, using trilateration."     },     {         "input": "What is the importance of signal processing in communication systems?",         "output": "Signal processing is crucial in communication systems for filtering, compressing, encoding, and decoding signals. It enhances signal quality, reduces noise, and ensures the accurate transmission of information over various channels."     },     {         "input": "Explain the concept of feedback in control systems.",         "output": "Feedback in control systems involves using the output of the system to adjust the input. This helps maintain desired performance, improves stability, and reduces the impact of disturbances by correcting errors in real-time."     },     {         "input": "What are the challenges in designing a high-speed train?",         "output": "Challenges in designing a high-speed train include aerodynamic drag, noise reduction, energy efficiency, track stability, passenger comfort, and safety systems. Advanced materials and technologies are also needed to achieve and maintain high speeds."     },     {         "input": "Discuss the role of encryption in securing communication systems.",         "output": "Encryption secures communication systems by converting data into a code to prevent unauthorized access. It ensures the confidentiality, integrity, and authenticity of the transmitted information, protecting it from eavesdropping and tampering."     },     {         "input": "How do sensors and actuators interact in an embedded system?",         "output": "In an embedded system, sensors collect data from the environment, which is processed by the microcontroller. Based on this data, the microcontroller sends signals to actuators, which then perform the desired action, such as turning a motor or opening a valve."     },     {         "input": "What is the purpose of a digital signal processor (DSP)?",         "output": "A Digital Signal Processor (DSP) is specialized for the high-speed processing of signals. It performs operations such as filtering, modulation, and encoding, which are essential in applications like audio processing, telecommunications, and image analysis."     },     {         "input": "Explain the working principle of an electric motor.",         "output": "An electric motor works on the principle of electromagnetic induction. When an electric current passes through a coil within a magnetic field, it generates a force that causes the motor's rotor to turn, converting electrical energy into mechanical energy."     },     {         "input": "What are the factors that affect the performance of an antenna?",         "output": "Factors affecting antenna performance include its design (shape, size), frequency of operation, placement, surrounding environment, and impedance matching. These factors influence the antenna's gain, bandwidth, and radiation pattern."     },     {         "input": "Discuss the significance of the Nyquist theorem in signal processing.",         "output": "The Nyquist theorem states that a continuous signal can be completely reconstructed from its samples if it is sampled at a rate at least twice its highest frequency component. It is fundamental in preventing aliasing and ensuring accurate signal reproduction."     },
  {         "input": "What is the difference between a synchronous and an asynchronous motor?",         "output": "A synchronous motor runs at a constant speed synchronized with the supply frequency, while an asynchronous (induction) motor's speed varies depending on the load and is not directly proportional to the supply frequency."     },     {         "input": "Explain the concept of load balancing in computer networks.",         "output": "Load balancing in computer networks involves distributing incoming network traffic across multiple servers to ensure no single server becomes overwhelmed. This improves performance, reliability, and availability of network services."     },     {         "input": "What is the function of a rectifier in electronic circuits?",         "output": "A rectifier converts alternating current (AC) to direct current (DC). It is used in power supplies to provide the necessary DC voltage for electronic circuits, ensuring proper operation of electronic devices."     },     {         "input": "How does a phased array radar differ from a conventional radar?",         "output": "A phased array radar uses multiple antenna elements whose signals are electronically controlled to steer the beam in different directions without moving the antenna physically. This provides faster scanning and tracking compared to conventional radar."     },     {         "input": "Describe the working principle of a thermoelectric generator.",         "output": "A thermoelectric generator converts heat into electrical energy using the Seebeck effect. When there is a temperature difference between two different conductive materials, it generates a voltage, which can be harnessed for power."     },     {         "input": "What are the advantages of using CMOS technology in integrated circuits?",         "output": "CMOS technology offers low power consumption, high noise immunity, and greater density of logic functions in integrated circuits. It is widely used in microprocessors, sensors, and other digital and analog circuits."     },     {         "input": "What is the role of a heat sink in electronic devices?",         "output": "A heat sink dissipates heat generated by electronic devices, such as CPUs or power transistors, to prevent overheating. It improves thermal management and ensures the reliable operation of the device."     },     {         "input": "Explain the difference between primary and secondary batteries.",         "output": "Primary batteries are non-rechargeable and are designed for single-use, while secondary batteries are rechargeable and can be used multiple times. Primary batteries are used in low-drain devices, whereas secondary batteries are used in high-drain and portable devices."     },     {         "input": "Discuss the importance of electromagnetic compatibility (EMC) in electronic design.",         "output": "EMC ensures that electronic devices operate without causing or being affected by electromagnetic interference. It is crucial for the reliable performance of devices, especially in environments with multiple electronic systems."     },     {         "input": "What is the significance of Moore's Law in the development of microelectronics?",         "output": "Moore's Law predicts that the number of transistors on a microchip doubles approximately every two years, leading to exponential growth in computing power. This has driven advancements in microelectronics and the development of smaller, faster, and more efficient devices."     },     {         "input": "How does a pulse-width modulation (PWM) technique work in motor control?",         "output": "PWM controls the power delivered to a motor by varying the width of the voltage pulses. By adjusting the duty cycle, it regulates the motor's speed and torque, offering precise control in applications such as robotics and electric vehicles."     },     {         "input": "Explain the concept of artificial intelligence in autonomous systems.",         "output": "Artificial intelligence in autonomous systems enables machines to perform tasks that typically require human intelligence. It involves algorithms for perception, decision-making, and learning, allowing systems to adapt to changing environments and operate independently."     },     {         "input": "What is the purpose of a phase-locked loop (PLL) in communication systems?",         "output": "A PLL is used in communication systems to synchronize the frequency of an oscillator with a reference signal. It is essential for demodulation, frequency synthesis, and clock generation, ensuring accurate and stable signal transmission."     },     {         "input": "What is nuclear fission?",         "output": "Nuclear fission is the process of splitting a large atomic nucleus into smaller particles, often producing free neutrons and photons (in the form of gamma rays) and releasing a significant amount of energy."     },
{     "input": "What is the difference between nuclear fission and nuclear fusion?",     "output": "Nuclear fission involves splitting a large nucleus into smaller particles, releasing energy, while nuclear fusion involves combining light nuclei to form a heavier nucleus, also releasing energy. Fusion is the process that powers stars, including the Sun."   },   {     "input": "What is a nuclear reactor and how does it work?",     "output": "A nuclear reactor is a device used to initiate and control a sustained nuclear chain reaction. It works by using fuel rods containing fissile material, such as uranium-235, which undergo fission. The heat generated is used to produce steam, which drives turbines to generate electricity."   },   {     "input": "What are control rods and what is their function in a nuclear reactor?",     "output": "Control rods are made of materials that absorb neutrons, such as boron or cadmium. They are inserted into the reactor core to control the rate of the nuclear chain reaction by absorbing excess neutrons, thereby regulating the reactor's power output."   },   {     "input": "What is the purpose of a moderator in a nuclear reactor?",     "output": "A moderator is a material used in a nuclear reactor to slow down fast neutrons, increasing the likelihood of further fission reactions. Common moderators include water, heavy water, and graphite."   },   {     "input": "What are some safety measures used in nuclear reactors?",     "output": "Safety measures in nuclear reactors include containment structures to prevent the release of radioactive materials, emergency cooling systems to prevent overheating, redundant safety systems, regular maintenance and inspections, and strict operational protocols."   },   {     "input": "What is radioactive decay?",     "output": "Radioactive decay is the process by which an unstable atomic nucleus loses energy by emitting radiation. This can include alpha particles, beta particles, or gamma rays, transforming the original nucleus into a different element or a different isotope of the same element."   },   {     "input": "What are the main types of radiation, and how do they differ?",     "output": "The main types of radiation are alpha, beta, and gamma radiation. Alpha particles are heavy and carry a positive charge, beta particles are lighter and carry a negative charge, and gamma rays are high-energy electromagnetic waves. Alpha particles have low penetration power, beta particles have moderate penetration power, and gamma rays have high penetration power."   },   {     "input": "What is half-life in the context of radioactive materials?",     "output": "The half-life of a radioactive material is the time it takes for half of the radioactive atoms in a sample to decay. It is a measure of the rate at which the material undergoes radioactive decay."   },   {     "input": "What are the potential risks and benefits of nuclear energy?",     "output": "The benefits of nuclear energy include a high energy output with low greenhouse gas emissions, and a reliable power supply. The risks include the potential for nuclear accidents, the challenge of managing radioactive waste, and the possibility of nuclear proliferation."   },   {     "input": "What is uranium enrichment and why is it necessary?",     "output": "Uranium enrichment is the process of increasing the proportion of the uranium-235 isotope in uranium. This is necessary because natural uranium contains only about 0.7% uranium-235, and most nuclear reactors require a higher concentration (typically 3-5%) to sustain a chain reaction."   },   {     "input": "What is a nuclear chain reaction?",     "output": "A nuclear chain reaction occurs when a single nuclear reaction causes an average of one or more subsequent nuclear reactions, leading to a self-sustaining series of these reactions. This is the principle behind both nuclear reactors and nuclear weapons."   },   {     "input": "What is the role of coolant in a nuclear reactor?",     "output": "The coolant in a nuclear reactor is used to remove heat from the reactor core and transfer it to a steam generator or directly to the turbines. Common coolants include water, heavy water, and liquid metals such as sodium or lead."   },   {     "input": "What is the difference between a pressurized water reactor (PWR) and a boiling water reactor (BWR)?",     "output": "In a PWR, water is kept under high pressure to prevent it from boiling, and heat is transferred to a secondary loop to generate steam. In a BWR, water boils directly in the reactor core, and the steam generated is used to drive the turbines."   },   {     "input": "What is nuclear waste and how is it managed?",     "output": "Nuclear waste is the radioactive material that remains after nuclear fuel has been used in a reactor. It is managed through storage in specially designed facilities, reprocessing to extract usable materials, and disposal in deep geological repositories."   },   {     "input": "What are some common types of nuclear reactors?",     "output": "Common types of nuclear reactors include pressurized water reactors (PWRs), boiling water reactors (BWRs), heavy water reactors (HWRs), gas-cooled reactors (GCRs), and fast breeder reactors (FBRs)."   },   {     "input": "What is the role of the International Atomic Energy Agency (IAEA)?",     "output": "The IAEA is an international organization that promotes the peaceful use of nuclear energy, ensures the safe and secure operation of nuclear facilities, and works to prevent the spread of nuclear weapons."   },   {     "input": "What is a meltdown in a nuclear reactor?",     "output": "A meltdown is a severe nuclear reactor accident that occurs when the reactor core overheats to the point where the fuel rods begin to melt. This can lead to the release of radioactive materials if containment measures fail."   },   {     "input": "What are isotopes and why are they important in nuclear technology?",     "output": "Isotopes are atoms of the same element that have different numbers of neutrons. They are important in nuclear technology because certain isotopes, like uranium-235 and plutonium-239, are fissile and can sustain nuclear chain reactions."   },   {     "input": "What is the difference between fissile and fertile materials?",     "output": "Fissile materials can sustain a nuclear chain reaction with thermal neutrons, while fertile materials can be converted into fissile materials through neutron capture and subsequent nuclear reactions. Uranium-238 and thorium-232 are examples of fertile materials."   },
{     "input": "What is neutron moderation?",     "output": "Neutron moderation is the process of slowing down fast neutrons to thermal energies, where they are more likely to induce fission in fissile materials. This is typically achieved using a moderator such as water, heavy water, or graphite."   },   {     "input": "What is nuclear reprocessing?",     "output": "Nuclear reprocessing is the chemical separation of usable fissile materials (like uranium and plutonium) from spent nuclear fuel. This process allows for the recycling of nuclear materials and reduces the amount of high-level radioactive waste."   },   {     "input": "What is a breeder reactor?",     "output": "A breeder reactor is a type of nuclear reactor that generates more fissile material than it consumes. It does this by converting fertile materials, such as uranium-238 or thorium-232, into fissile isotopes like plutonium-239 or uranium-233."   },   {     "input": "What is a containment building in a nuclear power plant?",     "output": "A containment building is a reinforced structure that surrounds the reactor core and other critical components of a nuclear power plant. Its purpose is to contain the release of radioactive materials in the event of an accident."   },   {     "input": "What is a neutron cross-section?",     "output": "A neutron cross-section is a measure of the probability that a neutron will interact with a target nucleus, resulting in reactions such as absorption, scattering, or fission. It is usually expressed in units called barns."   },   {     "input": "What is the function of a steam generator in a nuclear power plant?",     "output": "A steam generator in a nuclear power plant transfers heat from the reactor coolant to a secondary loop, where water is converted into steam. The steam is then used to drive turbines and generate electricity."   },   {     "input": "What are some examples of passive safety features in nuclear reactors?",     "output": "Passive safety features in nuclear reactors rely on natural physical principles, such as gravity, natural circulation, and thermal expansion, to ensure the reactor remains safe without the need for active controls or human intervention. Examples include gravity-driven cooling systems and pressure-relief valves."   },   {     "input": "What is the purpose of a nuclear regulatory authority?",     "output": "A nuclear regulatory authority oversees the safe and secure operation of nuclear facilities within a country. It establishes regulations, conducts inspections, and enforces compliance to ensure the protection of public health and the environment."   },   {     "input": "What are composite materials?",     "output": "Composite materials are engineered materials made from two or more constituent materials with different physical or chemical properties. When combined, they produce a material with characteristics different from the individual components."   },   {     "input": "Discuss the properties and applications of composite materials in defense.",     "output": "Composite materials in defense offer high strength-to-weight ratios, corrosion resistance, and durability. They are used in aircraft, armor, and naval vessels to enhance performance, reduce weight, and increase survivability."   },   {     "input": "What is the significance of fiber-reinforced composites?",     "output": "Fiber-reinforced composites, such as carbon or glass fiber composites, are significant because they offer high strength and stiffness while being lightweight. They are extensively used in aerospace, automotive, and sporting goods."   },   {     "input": "Explain the role of the matrix in a composite material.",     "output": "The matrix in a composite material binds the fibers together, transfers loads between them, and protects them from environmental damage. It plays a crucial role in determining the composite's overall properties."   },   {     "input": "What are ceramic matrix composites (CMCs), and where are they used?",     "output": "Ceramic matrix composites (CMCs) are materials made by reinforcing ceramic matrices with ceramic fibers. They are used in high-temperature applications, such as turbine blades and heat shields, due to their excellent thermal resistance."   },   {     "input": "How does thermal fatigue affect the performance of aerospace materials?",     "output": "Thermal fatigue causes damage to aerospace materials due to repeated thermal cycling, leading to microcracks, delamination, and eventual failure. It affects the lifespan and reliability of components like turbine blades and airframes."   },   {     "input": "What is the importance of carbon-carbon composites in aerospace?",     "output": "Carbon-carbon composites are crucial in aerospace due to their ability to withstand extremely high temperatures without losing strength. They are used in applications like re-entry vehicle nose cones and brake discs in aircraft."   },   {     "input": "Describe the process of pultrusion in composite manufacturing.",     "output": "Pultrusion is a continuous manufacturing process where fibers are pulled through a resin bath and then through a heated die to form a composite profile. It is used to produce strong, lightweight structural components."   },   {     "input": "What are the advantages of using composites over metals?",     "output": "Composites offer advantages such as higher strength-to-weight ratios, corrosion resistance, and design flexibility compared to metals. They also allow for more complex shapes and are often easier to repair."   },   {     "input": "Explain the concept of anisotropy in composite materials.",     "output": "Anisotropy in composite materials refers to the directional dependence of their properties. The strength and stiffness of composites can vary depending on the orientation of the fibers, unlike isotropic materials like metals."   },   {     "input": "What are the challenges associated with the use of composites in structural applications?",     "output": "Challenges include the difficulty in predicting long-term behavior, issues with joining and repairing composite structures, and higher initial costs compared to traditional materials."   },   {     "input": "What is the role of nanoparticles in enhancing composite materials?",     "output": "Nanoparticles can enhance the mechanical, thermal, and electrical properties of composite materials by improving the load transfer between the matrix and the reinforcement and by adding functionalities like conductivity or flame retardancy."   },   {     "input": "What is the significance of Kevlar in defense applications?",     "output": "Kevlar is a high-strength synthetic fiber known for its exceptional impact resistance. It is widely used in bulletproof vests, helmets, and other protective gear in defense applications due to its lightweight and durable nature."   },
{         "input": "What is neutron moderation?",         "output": "Neutron moderation is the process of slowing down fast neutrons to thermal energies, where they are more likely to induce fission in fissile materials. This is typically achieved using a moderator such as water, heavy water, or graphite."     },     {         "input": "What is nuclear reprocessing?",         "output": "Nuclear reprocessing is the chemical separation of usable fissile materials (like uranium and plutonium) from spent nuclear fuel. This process allows for the recycling of nuclear materials and reduces the amount of high-level radioactive waste."     },     {         "input": "What is a breeder reactor?",         "output": "A breeder reactor is a type of nuclear reactor that generates more fissile material than it consumes. It does this by converting fertile materials, such as uranium-238 or thorium-232, into fissile isotopes like plutonium-239 or uranium-233."     },     {         "input": "What is a containment building in a nuclear power plant?",         "output": "A containment building is a reinforced structure that surrounds the reactor core and other critical components of a nuclear power plant. Its purpose is to contain the release of radioactive materials in the event of an accident."     },     {         "input": "What is a neutron cross-section?",         "output": "A neutron cross-section is a measure of the probability that a neutron will interact with a target nucleus, resulting in reactions such as absorption, scattering, or fission. It is usually expressed in units called barns."     },     {         "input": "What is the function of a steam generator in a nuclear power plant?",         "output": "A steam generator in a nuclear power plant transfers heat from the reactor coolant to a secondary loop, where water is converted into steam. The steam is then used to drive turbines and generate electricity."     },     {         "input": "What are some examples of passive safety features in nuclear reactors?",         "output": "Passive safety features in nuclear reactors rely on natural physical principles, such as gravity, natural circulation, and thermal expansion, to ensure the reactor remains safe without the need for active controls or human intervention. Examples include gravity-driven cooling systems and pressure-relief valves."     },     {         "input": "What is the purpose of a nuclear regulatory authority?",         "output": "A nuclear regulatory authority oversees the safe and secure operation of nuclear facilities within a country. It establishes regulations, conducts inspections, and enforces compliance to ensure the protection of public health and the environment."     },     {         "input": "What are composite materials?",         "output": "Composite materials are engineered materials made from two or more constituent materials with different physical or chemical properties. When combined, they produce a material with characteristics different from the individual components."     },     {         "input": "Discuss the properties and applications of composite materials in defense.",         "output": "Composite materials in defense offer high strength-to-weight ratios, corrosion resistance, and durability. They are used in aircraft, armor, and naval vessels to enhance performance, reduce weight, and increase survivability."     },     {         "input": "What is the significance of fiber-reinforced composites?",         "output": "Fiber-reinforced composites, such as carbon or glass fiber composites, are significant because they offer high strength and stiffness while being lightweight. They are extensively used in aerospace, automotive, and sporting goods."     },     {         "input": "Explain the role of the matrix in a composite material.",         "output": "The matrix in a composite material binds the fibers together, transfers loads between them, and protects them from environmental damage. It plays a crucial role in determining the composite's overall properties."     },     {         "input": "What are ceramic matrix composites (CMCs), and where are they used?",         "output": "Ceramic matrix composites (CMCs) are materials made by reinforcing ceramic matrices with ceramic fibers. They are used in high-temperature applications, such as turbine blades and heat shields, due to their excellent thermal resistance."     },     {         "input": "How does thermal fatigue affect the performance of aerospace materials?",         "output": "Thermal fatigue causes damage to aerospace materials due to repeated thermal cycling, leading to microcracks, delamination, and eventual failure. It affects the lifespan and reliability of components like turbine blades and airframes."     },     {         "input": "What is the importance of carbon-carbon composites in aerospace?",         "output": "Carbon-carbon composites are crucial in aerospace due to their ability to withstand extremely high temperatures without losing strength. They are used in applications like re-entry vehicle nose cones and brake discs in aircraft."     },     {         "input": "Describe the process of pultrusion in composite manufacturing.",         "output": "Pultrusion is a continuous manufacturing process where fibers are pulled through a resin bath and then through a heated die to form a composite profile. It is used to produce strong, lightweight structural components."     },     {         "input": "What are the advantages of using composites over metals?",         "output": "Composites offer advantages such as higher strength-to-weight ratios, corrosion resistance, and design flexibility compared to metals. They also allow for more complex shapes and are often easier to repair."     },     {         "input": "Explain the concept of anisotropy in composite materials.",         "output": "Anisotropy in composite materials refers to the directional dependence of their properties. The strength and stiffness of composites can vary depending on the orientation of the fibers, unlike isotropic materials like metals."     },     {         "input": "What are the challenges associated with the use of composites in structural applications?",         "output": "Challenges include the difficulty in predicting long-term behavior, issues with joining and repairing composite structures, and higher initial costs compared to traditional materials."     },     {         "input": "What is the role of nanoparticles in enhancing composite materials?",         "output": "Nanoparticles can enhance the mechanical, thermal, and electrical properties of composite materials by improving the load transfer between the matrix and the reinforcement and by adding functionalities like conductivity or flame retardancy."     },     {         "input": "What is the significance of Kevlar in defense applications?",         "output": "Kevlar is a high-strength synthetic fiber known for its exceptional impact resistance. It is widely used in bulletproof vests, helmets, and other protective gear in defense applications due to its lightweight and durable nature."     },     {         "input": "How do composite materials contribute to stealth technology?",         "output": "Composite materials contribute to stealth technology by reducing radar cross-section (RCS) through their ability to absorb or scatter radar waves. They are used in the construction of stealth aircraft and naval vessels."     },     {         "input": "Explain the process of vacuum-assisted resin transfer molding (VARTM).",         "output": "VARTM is a composite manufacturing process where a dry fiber preform is placed in a mold and a vacuum is applied to draw resin into the mold, saturating the fibers. It is used to produce large, complex composite parts with high quality."     },     {         "input": "What are the effects of moisture absorption on composite materials?",         "output": "Moisture absorption can degrade composite materials by causing swelling, reducing mechanical properties, and leading to delamination. This is especially critical in marine and aerospace environments."     },     {         "input": "Describe the role of epoxy resins in composite materials.",         "output": "Epoxy resins are commonly used as matrices in composite materials due to their strong adhesive properties, chemical resistance, and excellent mechanical performance. They are widely used in aerospace, automotive, and construction industries."     },     {         "input": "What is the significance of the specific modulus in materials science?",         "output": "The specific modulus is the ratio of a material's modulus of elasticity to its density. It is significant because it indicates the stiffness of a material relative to its weight, which is important in aerospace and other weight-sensitive applications."     },     {         "input": "How are metal matrix composites (MMCs) different from polymer matrix composites (PMCs)?",         "output": "MMCs use a metal matrix, offering higher temperature resistance and strength compared to PMCs, which use a polymer matrix. MMCs are used in high-performance applications like automotive engines and aerospace components."     },     {         "input": "What is creep, and how does it affect material performance?",         "output": "Creep is the gradual deformation of a material under constant stress over time, typically at high temperatures. It affects material performance by leading to dimensional changes and potential failure in structural components."     },     {         "input": "Explain the role of thermal barrier coatings (TBCs) in aerospace materials.",         "output": "TBCs are applied to aerospace components to protect them from high temperatures, reducing thermal fatigue and extending the life of the components. They are commonly used on turbine blades and engine parts."     },     {         "input": "What are shape memory alloys, and where are they used?",         "output": "Shape memory alloys (SMAs) are materials that can return to their original shape after being deformed, when subjected to the appropriate thermal or mechanical stimulus. They are used in actuators, medical devices, and aerospace applications."     },     {         "input": "What is fatigue in materials, and how is it tested?",         "output": "Fatigue is the weakening of a material caused by repeated cyclic loading, leading to the formation of cracks and eventual failure. It is tested by subjecting a specimen to controlled cyclic loads and measuring the number of cycles to failure."     },     {         "input": "Discuss the importance of fracture toughness in materials selection.",         "output": "Fracture toughness measures a material's ability to resist crack propagation. It is important in selecting materials for structural applications, especially where mechanical impact or stress concentrations may occur."     },     {         "input": "How does the addition of carbon fibers enhance the properties of a composite?",         "output": "Carbon fibers enhance the properties of a composite by providing high tensile strength, stiffness, and thermal stability, while also reducing weight. This makes them ideal for use in aerospace, automotive, and sporting goods."     },     {         "input": "What are the advantages of using thermoplastic composites?",         "output": "Thermoplastic composites offer advantages such as recyclability, high impact resistance, and the ability to be remolded. They also have faster processing times compared to thermosetting composites."     },     {         "input": "What is the role of non-destructive testing (NDT) in composite materials?",         "output": "NDT methods, such as ultrasound and X-ray, are used to inspect composite materials for defects without causing damage. They are critical in quality control and ensuring the integrity of composite structures in aerospace and other industries."     },     {         "input": "How does fiber orientation affect the mechanical properties of a composite material?",         "output": "Fiber orientation significantly affects the mechanical properties of a composite. Fibers aligned with the load direction provide maximum strength and stiffness, while off-axis fibers contribute to shear strength and impact resistance."     },     {         "input": "What is the impact of thermal expansion mismatch in composite materials?",         "output": "Thermal expansion mismatch between the matrix and reinforcement in a composite can lead to residual stresses, warping, or even cracking, especially during thermal cycling or exposure to extreme temperatures."     },     {         "input": "Explain the concept of laminate stacking sequence in composite materials.",         "output": "Laminate stacking sequence refers to the arrangement of individual layers (plies) of composite material with varying fiber orientations. The sequence is designed to optimize the mechanical properties for specific loading conditions."     },


]

# %%
df= pd.DataFrame(data)
print(df.head())
# Out:
#                                                input  \
# 0  question: What is DRDO, and what are its prima...
# 1  question: Explain the concept of missile guida...
# 2  question: What is the difference between a rad...
# 3    question: How does an active radar system work?
# 4  question: What are the key components of a com...
#
#                                               output
# 0  DRDO (Defence Research and Development Organis...
# 1  Missile guidance systems direct a missile to i...
# 2  Radar uses radio waves to detect and locate ob...
# 3  An active radar system transmits its own signa...
# 4  Key components include satellites (with transp...

# %%
train_df_data , val_df_data = train_test_split(df  ,test_size = 0.1)

train_data  = Dataset.from_pandas(train_df_data)

validation_data = Dataset.from_pandas(val_df_data)

for i in train_data:
   print(i)
# Out:
# {'input': 'question: Explain the concept of a command and control (C2) system.', 'output': 'A C2 system integrates data and communications to facilitate decision-making, coordination, and control of military operations, ensuring effective management of resources and personnel.', '__index_level_0__': 23}
# {'input': 'What is the significance of fiber-reinforced composites?', 'output': 'Fiber-reinforced composites, such as carbon or glass fiber composites, are significant because they offer high strength and stiffness while being lightweight. They are extensively used in aerospace, automotive, and sporting goods.', '__index_level_0__': 139}
# ...

# %%
from transformers import T5Tokenizer , T5ForConditionalGeneration

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-small')

model = T5ForConditionalGeneration.from_pretrained('t5-small')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def preprocess(datas):

  inp = [x for x in datas['input']]

  out = [x for x in datas['output']]
  print(out)


  model_inp = tokenizer(inp , max_length=128 ,truncation=True , padding='max_length')

  with tokenizer.as_target_tokenizer():

    labels = tokenizer(out ,  max_length=128 ,truncation=True , padding='max_length')
  # print(labels)
  model_inp["labels"] = labels["input_ids"]
  # for input_ids, label_ids in zip(model_inp["labels"], labels["input_ids"]):
  #   decoded_input = tokenizer.decode(input_ids, skip_special_tokens=True)
  #   decoded_label = tokenizer.decode(label_ids, skip_special_tokens=True)
  #   print(f"Input: {decoded_input} ======>>>> Label: {decoded_label}")
  # # print(labels["output"])
  # print(model_inp["labels"])

  final_data_for_train = model_inp

  return final_data_for_train
  # print(final_data_for_train)

# %%
token_train_data = train_data.map(preprocess , batched=True)

token_val_data = validation_data.map(preprocess , batched=True)

print(token_train_data)

print(token_val_data)

# for i in token_train_data:

#   for input_ids, label_ids in zip(token_train_data["labels"], token_train_data["input_ids"]):
#     decoded_input = tokenizer.decode(input_ids, skip_special_tokens=True)
#     decoded_label = tokenizer.decode(label_ids, skip_special_tokens=True)
#     print(f"Input: {decoded_input} ======>>>> Label: {decoded_label}")

print()

for i in token_val_data:

  print(tokenizer.decode(i['labels']), tokenizer.decode(i['input_ids']))
# Out:
# Map:   0%|          | 0/169 [00:00<?, ? examples/s]
# ...

# %%
# !pip install accelerate -U
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...

# %%
# import
from transformers import TrainingArguments , Trainer

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=50,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch",
    learning_rate=5e-5
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = token_train_data,
    eval_dataset = token_val_data
)

# %%
trainer.train()
model.save_pretrained("./t5_nmap_model")
tokenizer.save_pretrained("./t5_nmap_tokenizer")
# Out:
#     <div>
#
#       <progress value='2150' max='2150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2150/2150 04:24, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>10.541600</td>
#       <td>10.180290</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>9.356200</td>
#       <td>8.231121</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.245500</td>
#       <td>5.061832</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.657700</td>
#       <td>2.008132</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.424800</td>
#       <td>1.439705</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.024100</td>
#       <td>1.352308</td>
#     </tr>
#     <tr>
#       <td>7</td>
# ...

# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration


tokenizer = T5Tokenizer.from_pretrained('./t5_nmap_tokenizer')
model = T5ForConditionalGeneration.from_pretrained('./t5_nmap_model')


input_query = input()


inputs = tokenizer.encode("question: " + input_query, return_tensors="pt")

outputs = model.generate(inputs, max_length=128, num_beams=4, early_stopping=True)


predicted_answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(f"Input Query: {input_query}")
print(f"Predicted Answer: {predicted_answer}")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Explain the concept of VSWR and its importance.
# Input Query: Explain the concept of VSWR and its importance.
# Predicted Answer: VSWR measures the effectiveness of a vehicle, its effectiveness, and its effectiveness.

# %%
# !pip install transformers datasets
# import pandas as pd
# from datasets import Dataset
# from sklearn.model_selection import train_test_split
# from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments
# data = [
#     {"input": "Identify reachable IP addresses using Nmap, excluding 192.168.1.1.", "output": "nmap 192.168.1.0/24 --exclude 192.168.1.1"},
#     {"input": "Scan the local network for active services.", "output": "nmap 192.168.1.0/24"},
#     {"input": "Investigate which devices are online in the 192.168.1.0/24 subnet.", "output": "nmap 192.168.1.0/24"},
#     {"input": "Perform an Nmap scan on the IP addresses listed in targets.txt.", "output": "nmap -iL targets.txt"},
#     {"input": "Scan a random set of 100 IP addresses.", "output": "nmap -iR 100"},
#     {"input": "Probe 192.168.1.1 for open ports using Nmap’s SYN scan.", "output": "nmap 192.168.1.1 -sS"},
#     {"input": "Check for open ports on 192.168.1.0/24 network using Nmap.", "output": "nmap 192.168.1.0/24 -p 1-65535"},
#     {"input": "Perform an intense scan on 192.168.1.0/24 subnet with Nmap.", "output": "nmap -T4 -A -v 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and output results to a file.", "output": "nmap -oN scan_results.txt 192.168.1.0/24"},
#     {"input": "Identify live hosts on the local network using Nmap.", "output": "nmap -sn 192.168.1.0/24"},
#     {"input": "Perform a stealth scan on 192.168.1.0/24 subnet with Nmap.", "output": "nmap -sS 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and only show open ports.", "output": "nmap --open 192.168.1.0/24"},
#     {"input": "Check for vulnerable services on 192.168.1.0/24 subnet using Nmap.", "output": "nmap --script vuln 192.168.1.0/24"},
#     {"input": "Probe 192.168.1.0/24 for services with Nmap's version detection.", "output": "nmap -sV 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a UDP scan.", "output": "nmap -sU 192.168.1.0/24"},
#     {"input": "Identify OS of devices in 192.168.1.0/24 subnet using Nmap.", "output": "nmap -O 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a ping scan.", "output": "nmap -sP 192.168.1.0/24"},
#     {"input": "Perform a quick scan on 192.168.1.0/24 subnet with Nmap.", "output": "nmap -T4 -F 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and disable DNS resolution.", "output": "nmap -n 192.168.1.0/24"},
#     {"input": "Investigate live hosts on 192.168.1.0/24 subnet with aggressive scan.", "output": "nmap -A 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and detect firewall presence.", "output": "nmap -sA 192.168.1.0/24"},
#     {"input": "Check for SSL/TLS services on 192.168.1.0/24 subnet using Nmap.", "output": "nmap --script ssl-enum-ciphers 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a TCP connect scan.", "output": "nmap -sT 192.168.1.0/24"},
#     {"input": "Identify IP addresses in 192.168.1.0/24 subnet with Nmap.", "output": "nmap -sL 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and output results in XML format.", "output": "nmap -oX scan_results.xml 192.168.1.0/24"},
#     {"input": "Investigate which services are running on 192.168.1.0/24 subnet using Nmap.", "output": "nmap -sV -p 1-65535 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a service version detection.", "output": "nmap -sV 192.168.1.0/24"},
#     {"input": "Identify devices in 192.168.1.0/24 subnet with Nmap and display verbose output.", "output": "nmap -v 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a full port scan.", "output": "nmap -p- 192.168.1.0/24"},
#     {"input": "Investigate which IP addresses are up in the 192.168.1.0/24 subnet using Nmap.", "output": "nmap -sP 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and detect HTTP services.", "output": "nmap --script http-enum 192.168.1.0/24"},
#     {"input": "Check for SSH services on 192.168.1.0/24 subnet using Nmap.", "output": "nmap -p 22 192.168.1.0/24"},
#     {"input": "Probe 192.168.1.0/24 for open ports using Nmap with TCP SYN scan.", "output": "nmap -sS 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a stealthy scan with Nmap.", "output": "nmap -sS -T4 -A -v 192.168.1.0/24"},
#     {"input": "Investigate which devices are live in the 192.168.1.0/24 subnet using Nmap.", "output": "nmap -sn 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a UDP scan with Nmap.", "output": "nmap -sU 192.168.1.0/24"},
#     {"input": "Check for vulnerable services in the 192.168.1.0/24 subnet using Nmap.", "output": "nmap --script vuln 192.168.1.0/24"},
#     {"input": "Probe 192.168.1.0/24 for services with Nmap's version detection.", "output": "nmap -sV 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a ping scan using Nmap.", "output": "nmap -sP 192.168.1.0/24"},
#     {"input": "Identify OS of devices in 192.168.1.0/24 subnet with Nmap.", "output": "nmap -O 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a quick scan with Nmap.", "output": "nmap -T4 -F 192.168.1.0/24"},
#     {"input": "Check for open ports on 192.168.1.0/24 network using Nmap.", "output": "nmap -p 1-65535 192.168.1.0/24"},
#     {"input": "Investigate live hosts on the 192.168.1.0/24 subnet with Nmap.", "output": "nmap -A 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and detect firewall presence with Nmap.", "output": "nmap -sA 192.168.1.0/24"},
#     {"input": "Identify SSL/TLS services on 192.168.1.0/24 subnet using Nmap.", "output": "nmap --script ssl-enum-ciphers 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a TCP connect scan.", "output": "nmap -sT 192.168.1.0/24"},
#     {"input": "Identify IP addresses in 192.168.1.0/24 subnet with Nmap.", "output": "nmap -sL 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and output results in XML format.", "output": "nmap -oX scan_results.xml 192.168.1.0/24"},
#     {"input": "Investigate which services are running on 192.168.1.0/24 subnet using Nmap.", "output": "nmap -sV -p 1-65535 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a service version detection.", "output": "nmap -sV 192.168.1.0/24"},
#     {"input": "Identify devices in 192.168.1.0/24 subnet with Nmap and display verbose output.", "output": "nmap -v 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a full port scan.", "output": "nmap -p- 192.168.1.0/24"},
#     {"input": "Investigate which IP addresses are up in the 192.168.1.0/24 subnet using Nmap.", "output": "nmap -sP 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and detect HTTP services.", "output": "nmap --script http-enum 192.168.1.0/24"},
#     {"input": "Check for SSH services on 192.168.1.0/24 subnet using Nmap.", "output": "nmap -p 22 192.168.1.0/24"},
#     {"input": "Probe 192.168.1.0/24 for open ports using Nmap with TCP SYN scan.", "output": "nmap -sS 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a stealthy scan with Nmap.", "output": "nmap -sS -T4 -A -v 192.168.1.0/24"},
#     {"input": "Investigate which devices are live in the 192.168.1.0/24 subnet using Nmap.", "output": "nmap -sn 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a UDP scan with Nmap.", "output": "nmap -sU 192.168.1.0/24"},
#     {"input": "Check for vulnerable services in the 192.168.1.0/24 subnet using Nmap.", "output": "nmap --script vuln 192.168.1.0/24"},
#     {"input": "Probe 192.168.1.0/24 for services with Nmap's version detection.", "output": "nmap -sV 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a ping scan using Nmap.", "output": "nmap -sP 192.168.1.0/24"},
#     {"input": "Identify OS of devices in 192.168.1.0/24 subnet with Nmap.", "output": "nmap -O 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and perform a quick scan with Nmap.", "output": "nmap -T4 -F 192.168.1.0/24"},
#     {"input": "Check for open ports on 192.168.1.0/24 network using Nmap.", "output": "nmap -p 1-65535 192.168.1.0/24"},
#     {"input": "Investigate live hosts on the 192.168.1.0/24 subnet with Nmap.", "output": "nmap -A 192.168.1.0/24"},
#     {"input": "Scan 192.168.1.0/24 network and detect firewall presence with Nmap.", "output": "nmap -sA 192.168.1.0/24"},
#     {"input": "Identify SSL/TLS services on 192.168.1.0/24 subnet using Nmap.", "output": "nmap --script ssl-"}
# ]

# # Convert the data to DataFrame
# df = pd.DataFrame(data)
# train_df, val_df = train_test_split(df, test_size=0.2)
# train_dataset = Dataset.from_pandas(train_df)
# val_dataset = Dataset.from_pandas(val_df)
# tokenizer = T5Tokenizer.from_pretrained('t5-small')
# model = T5ForConditionalGeneration.from_pretrained('t5-small')
# def preprocess_function(examples):
#     inputs = [ex for ex in examples['input']]
#     targets = [ex for ex in examples['output']]
#     model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding='max_length')

#     # Setup the tokenizer for targets
#     with tokenizer.as_target_tokenizer():
#         labels = tokenizer(targets, max_length=128, truncation=True, padding='max_length')

#     model_inputs["labels"] = labels["input_ids"]
#     return model_inputs

# tokenized_train_dataset = train_dataset.map(preprocess_function, batched=True)
# tokenized_val_dataset = val_dataset.map(preprocess_function, batched=True)
# training_args = TrainingArguments(
#     output_dir='./results',
#     num_train_epochs=30,
#     per_device_train_batch_size=4,
#     per_device_eval_batch_size=4,
#     warmup_steps=500,
#     weight_decay=0.01,
#     logging_dir='./logs',
#     logging_steps=10,
#     evaluation_strategy="epoch",
# )
# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=tokenized_train_dataset,
#     eval_dataset=tokenized_val_dataset,
# )
# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=tokenized_train_dataset,
#     eval_dataset=tokenized_val_dataset,
# )
# trainer.train()
# model.save_pretrained('./t5_command_model')
# tokenizer.save_pretrained('./t5_command_model')
# def generate_command(input_query):
#     inputs = tokenizer.encode(input_query, return_tensors="pt")
#     outputs = model.generate(inputs, max_length=128, num_beams=4, early_stopping=True)
#     predicted_command = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     return predicted_command

# # Sample prediction
# input_query = "Identify reachable IP addresses using Nmap, excluding 192.168.1.1."
# predicted_command = generate_command(input_query)

# print(f"Input Query: {input_query}")
# print(f"Predicted Command: {predicted_command}")

# %%
# import pandas as pd
# from datasets import Dataset
# from sklearn.model_selection import train_test_split
# from transformers import BartTokenizer, BartForConditionalGeneration, Trainer, TrainingArguments

# # Define your data
# data = [
#     {"input": "Identify reachable IP addresses using Nmap, excluding 192.168.1.1.", "output": "nmap 192.168.1.0/24 --exclude 192.168.1.1"},
#     {"input": "Scan the local network for active services.", "output": "nmap 192.168.1.0/24"},
#     {"input": "Investigate which devices are online in the 192.168.1.0/24 subnet.", "output": "nmap 192.168.1.0/24"},
#     # Add more examples...
# ]

# # Convert the data to DataFrame
# df = pd.DataFrame(data)

# # Split the data into training and validation sets
# train_df, val_df = train_test_split(df, test_size=0.2)

# # Convert the data to Huggingface Dataset
# train_dataset = Dataset.from_pandas(train_df)
# val_dataset = Dataset.from_pandas(val_df)

# # Load tokenizer and model
# tokenizer = BartTokenizer.from_pretrained('facebook/bart-base')
# model = BartForConditionalGeneration.from_pretrained('facebook/bart-base')

# # Preprocess function
# def preprocess_function(examples):
#     inputs = examples['input']
#     targets = examples['output']
#     model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding='max_length')

#     # Setup the tokenizer for targets
#     with tokenizer.as_target_tokenizer():
#         labels = tokenizer(targets, max_length=128, truncation=True, padding='max_length')

#     model_inputs["labels"] = labels["input_ids"]
#     return model_inputs

# # Tokenize the datasets
# tokenized_train_dataset = train_dataset.map(preprocess_function, batched=True)
# tokenized_val_dataset = val_dataset.map(preprocess_function, batched=True)

# # Define training arguments
# training_args = TrainingArguments(
#     output_dir='./results',
#     num_train_epochs=3,
#     per_device_train_batch_size=4,
#     per_device_eval_batch_size=4,
#     warmup_steps=500,
#     weight_decay=0.01,
#     logging_dir='./logs',
#     logging_steps=10,
#     evaluation_strategy="epoch",
# )

# # Initialize the Trainer
# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=tokenized_train_dataset,
#     eval_dataset=tokenized_val_dataset,
# )

# # Train the model
# trainer.train()

# # Save the model and tokenizer
# model.save_pretrained('./bart_command_model')
# tokenizer.save_pretrained('./bart_command_model')

# # Function to generate commands
# def generate_command(input_query):
#     inputs = tokenizer.encode(input_query, return_tensors="pt")
#     outputs = model.generate(inputs, max_length=128, num_beams=4, early_stopping=True)
#     predicted_command = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     return predicted_command

# # Sample prediction
# input_query = "Identify reachable IP addresses using Nmap, excluding 192.168.1.1."
# predicted_command = generate_command(input_query)

# print(f"Input Query: {input_query}")
# print(f"Predicted Command: {predicted_command}")
